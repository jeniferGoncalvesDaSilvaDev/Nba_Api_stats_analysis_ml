# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferGoncalvesDaSilvaDev/Nba_Api_stats_analysis_ml/blob/main/nb_api_stats_analysis_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pegando os dados da api da estatísticas básicas da NBA

# %%
import pandas as pd

# Dataset com 30 jogadores
data = [
    # 25 jogadores já existentes
    {
        "player_id": 1,
        "name": "LeBron James",
        "age": 38,
        "position": "Forward",
        "team": "Los Angeles Lakers",
        "points_per_game": 25.7,
        "assists_per_game": 7.4,
        "rebounds_per_game": 8.2
    },
    {
        "player_id": 2,
        "name": "Stephen Curry",
        "age": 35,
        "position": "Guard",
        "team": "Golden State Warriors",
        "points_per_game": 30.4,
        "assists_per_game": 6.2,
        "rebounds_per_game": 5.3
    },
    # (Adicionando os outros jogadores existentes...)
    {
        "player_id": 25,
        "name": "Pascal Siakam",
        "age": 30,
        "position": "Forward",
        "team": "Toronto Raptors",
        "points_per_game": 23.2,
        "assists_per_game": 5.8,
        "rebounds_per_game": 7.8
    },

    # Adicionando mais 5 jogadores
    {
        "player_id": 26,
        "name": "Chris Paul",
        "age": 38,
        "position": "Guard",
        "team": "Golden State Warriors",
        "points_per_game": 13.0,
        "assists_per_game": 9.2,
        "rebounds_per_game": 4.3
    },
    {
        "player_id": 27,
        "name": "Kyrie Irving",
        "age": 31,
        "position": "Guard",
        "team": "Dallas Mavericks",
        "points_per_game": 27.1,
        "assists_per_game": 6.0,
        "rebounds_per_game": 4.8
    },
    {
        "player_id": 28,
        "name": "Rudy Gobert",
        "age": 31,
        "position": "Center",
        "team": "Minnesota Timberwolves",
        "points_per_game": 15.7,
        "assists_per_game": 1.2,
        "rebounds_per_game": 11.6
    },
    {
        "player_id": 29,
        "name": "Jamal Murray",
        "age": 27,
        "position": "Guard",
        "team": "Denver Nuggets",
        "points_per_game": 20.2,
        "assists_per_game": 6.3,
        "rebounds_per_game": 4.0
    },
    {
        "player_id": 30,
        "name": "Jalen Brunson",
        "age": 28,
        "position": "Guard",
        "team": "New York Knicks",
        "points_per_game": 24.0,
        "assists_per_game": 6.2,
        "rebounds_per_game": 3.5
    }
]

# Convertendo o JSON para um DataFrame
df = pd.DataFrame(data)

# Exibindo o DataFrame
print(df)
# Out:
#    player_id           name  age position                    team  \
# 0          1   LeBron James   38  Forward      Los Angeles Lakers
# 1          2  Stephen Curry   35    Guard   Golden State Warriors
# 2         25  Pascal Siakam   30  Forward         Toronto Raptors
# 3         26     Chris Paul   38    Guard   Golden State Warriors
# 4         27   Kyrie Irving   31    Guard        Dallas Mavericks
# 5         28    Rudy Gobert   31   Center  Minnesota Timberwolves
# 6         29   Jamal Murray   27    Guard          Denver Nuggets
# 7         30  Jalen Brunson   28    Guard         New York Knicks
#
#    points_per_game  assists_per_game  rebounds_per_game
# 0             25.7               7.4                8.2
# 1             30.4               6.2                5.3
# 2             23.2               5.8                7.8
# 3             13.0               9.2                4.3
# 4             27.1               6.0                4.8
# ...

# %%
df.head(6)
# Out:
#    player_id           name  age position                    team  \
# 0          1   LeBron James   38  Forward      Los Angeles Lakers
# 1          2  Stephen Curry   35    Guard   Golden State Warriors
# 2         25  Pascal Siakam   30  Forward         Toronto Raptors
# 3         26     Chris Paul   38    Guard   Golden State Warriors
# 4         27   Kyrie Irving   31    Guard        Dallas Mavericks
# 5         28    Rudy Gobert   31   Center  Minnesota Timberwolves
#
#    points_per_game  assists_per_game  rebounds_per_game
# 0             25.7               7.4                8.2
# 1             30.4               6.2                5.3
# 2             23.2               5.8                7.8
# 3             13.0               9.2                4.3
# 4             27.1               6.0                4.8
# 5             15.7               1.2               11.6

# %% [markdown]
# 1. Quais jogadores apresentam o melhor desempenho médio em pontos, assistências e rebotes por jogo?
# Identificar os jogadores mais consistentes nessas métricas básicas para entender quem são os principais jogadores em termos de impacto ofensivo e rebotes.

# %%
# Calcula a média simples das três estatísticas para cada jogador
df['average_performance'] = df[['points_per_game', 'assists_per_game', 'rebounds_per_game']].mean(axis=1)

# Encontra o jogador com o melhor desempenho médio
best_player = df.loc[df['average_performance'].idxmax()]

best_player
# Out:
# player_id                                  2
# name                           Stephen Curry
# age                                       35
# position                               Guard
# team                   Golden State Warriors
# points_per_game                         30.4
# assists_per_game                         6.2
# rebounds_per_game                        5.3
# average_performance                13.966667
# Name: 1, dtype: object

# %%
# Ordena o DataFrame pelo desvio padrão em ordem crescente
df_sorted = df.sort_values(by=['average_performance'],ascending=False)

# Seleciona os 5 primeiros jogadores com o menor desvio padrão
top_players = df_sorted.head(5) # Você pode alterar o número 5 para a quantidade desejada

# Exibe o resultado
#print(top_players[['name', 'average_performance']])

top_players = df_sorted.head(5) # Você pode alterar o número 5 para a quantidade desejada

# Exibe o resultado
print(top_players[['name', 'average_performance']])
# Out:
#             name  average_performance
# 1  Stephen Curry            13.966667
# 0   LeBron James            13.766667
# 4   Kyrie Irving            12.633333
# 2  Pascal Siakam            12.266667
# 7  Jalen Brunson            11.233333

# %% [markdown]
# 2. Quais são os jogadores mais equilibrados entre pontos, assistências e rebotes?
# Encontrar os atletas que têm um desempenho equilibrado em todas as três métricas, o que indica versatilidade e capacidade de contribuir em diversas áreas do jogo.

# %%
# Calcula o desvio padrão por estatística
df['var_player'] = df[['points_per_game', 'assists_per_game', 'rebounds_per_game']].std(axis=1)
df[['name','var_player']]
# Out:
#             name  var_player
# 0   LeBron James   10.342308
# 1  Stephen Curry   14.238797
# 2  Pascal Siakam    9.521204
# 3     Chris Paul    4.361575
# 4   Kyrie Irving   12.542860
# 5    Rudy Gobert    7.474624
# 6   Jamal Murray    8.764892
# 7  Jalen Brunson   11.138372

# %%
# Calcula a média simples das três estatísticas para cada jogador
df['var_player'] = df[['points_per_game', 'assists_per_game', 'rebounds_per_game']].std(axis=1)

# Encontra o jogador com o menor desvio padrão
player= df.loc[df['var_player'].idxmin()]

player
# Out:
# player_id                                 26
# name                              Chris Paul
# age                                       38
# position                               Guard
# team                   Golden State Warriors
# points_per_game                         13.0
# assists_per_game                         9.2
# rebounds_per_game                        4.3
# var_player                          4.361575
# average_performance                 8.833333
# Name: 3, dtype: object

# %%
# Ordena o DataFrame pelo desvio padrão em ordem crescente
df_sorted = df.sort_values(by=['var_player'])

# Seleciona os 5 primeiros jogadores com o menor desvio padrão
top_players = df_sorted.head(5) # Você pode alterar o número 5 para a quantidade desejada

# Exibe o resultado
print(top_players[['name', 'var_player']])
# Out:
#             name  var_player
# 3     Chris Paul    4.361575
# 5    Rudy Gobert    7.474624
# 6   Jamal Murray    8.764892
# 2  Pascal Siakam    9.521204
# 0   LeBron James   10.342308

# %% [markdown]
# 3. Como o desempenho dos jogadores varia entre as posições (Guard, Forward, Center)?
# Analisar como jogadores de diferentes posições se destacam em pontos, assistências e rebotes, o que pode ajudar a ajustar as táticas de acordo com as características da posição.

# %%
# Calcula a média simples das três estatísticas para cada jogador
df['var_player'] = df[['points_per_game', 'assists_per_game', 'rebounds_per_game']].std(axis=1)

# Encontra o desvio padrão das posições
player=  df[['var_player', 'name', 'position']]
player
# Out:
#    var_player           name position
# 0   10.342308   LeBron James  Forward
# 1   14.238797  Stephen Curry    Guard
# 2    9.521204  Pascal Siakam  Forward
# 3    4.361575     Chris Paul    Guard
# 4   12.542860   Kyrie Irving    Guard
# 5    7.474624    Rudy Gobert   Center
# 6    8.764892   Jamal Murray    Guard
# 7   11.138372  Jalen Brunson    Guard

# %%
# Ordena o DataFrame pelo desvio padrão em ordem crescente
df_sorted = df.sort_values(by=['var_player'])

# Seleciona os 5 primeiros jogadores com o menor desvio padrão
top_players = df_sorted.head(5) # Você pode alterar o número 5 para a quantidade desejada

# Exibe o resultado
print(top_players[['name', 'position', 'var_player']])
# Out:
#             name position  var_player
# 3     Chris Paul    Guard    4.361575
# 5    Rudy Gobert   Center    7.474624
# 6   Jamal Murray    Guard    8.764892
# 2  Pascal Siakam  Forward    9.521204
# 0   LeBron James  Forward   10.342308

# %% [markdown]
# Qual equipe possui os jogadores com a maior média de pontos, assistências e rebotes?
# Comparar as equipes no dataset para identificar quais times têm os jogadores com melhor desempenho nessas métricas, ajudando a prever possíveis pontos fortes e fracos de adversários.

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'age', 'position', 'team', 'points_per_game',
#        'assists_per_game', 'rebounds_per_game'],
#       dtype='object')

# %%
team_points = df[['team', 'points_per_game']]
team_rebounds = df[['team', 'rebounds_per_game']]
team_assists = df[['team', 'assists_per_game']]

# %%
print(team_points)
# Out:
#                      team  points_per_game
# 0      Los Angeles Lakers             25.7
# 1   Golden State Warriors             30.4
# 2         Toronto Raptors             23.2
# 3   Golden State Warriors             13.0
# 4        Dallas Mavericks             27.1
# 5  Minnesota Timberwolves             15.7
# 6          Denver Nuggets             20.2
# 7         New York Knicks             24.0

# %%
print(team_rebounds)
# Out:
#                      team  rebounds_per_game
# 0      Los Angeles Lakers                8.2
# 1   Golden State Warriors                5.3
# 2         Toronto Raptors                7.8
# 3   Golden State Warriors                4.3
# 4        Dallas Mavericks                4.8
# 5  Minnesota Timberwolves               11.6
# 6          Denver Nuggets                4.0
# 7         New York Knicks                3.5

# %%
print(team_assists)
# Out:
#                      team  assists_per_game
# 0      Los Angeles Lakers               7.4
# 1   Golden State Warriors               6.2
# 2         Toronto Raptors               5.8
# 3   Golden State Warriors               9.2
# 4        Dallas Mavericks               6.0
# 5  Minnesota Timberwolves               1.2
# 6          Denver Nuggets               6.3
# 7         New York Knicks               6.2

# %%
# @title Team Assists Per Game

import matplotlib.pyplot as plt

# Assuming your data is in a pandas DataFrame called 'df'
plt.figure(figsize=(10, 6))
plt.bar(df['team'], df['assists_per_game'])
plt.xlabel('Team')
plt.ylabel('Assists Per Game')
plt.title('Team Assists Per Game')
_ = plt.xticks(rotation=45, ha='right')

# %%
# @title Rebounds per Game by Team

import matplotlib.pyplot as plt

# Assuming your data is in a pandas DataFrame called 'df'
plt.figure(figsize=(10, 6))
plt.bar(df['team'], df['rebounds_per_game'],color='grey')
plt.xlabel('Team')
plt.ylabel('Rebounds per Game')
plt.title('Rebounds per Game by Team')
_ = plt.xticks(rotation=45, ha='right')

# %%
team = team_points["team"]
points_per_game= team_points["points_per_game"]

# %%
#Ensure both lists have the same length
min_len = min(len(team), len(points_per_game))
team = team[:min_len]
points_per_game = points_per_game[:min_len]


plt.figure(figsize=(10, 6))
plt.bar(team, points_per_game, color='skyblue')
plt.xlabel('Team')
plt.ylabel('Points Per Game')
plt.title('Points Per Game by Team')
_ = plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability

# %% [markdown]
# Quem são os jogadores mais eficazes em cada uma das métricas individuais (quem marca mais pontos, dá mais assistências ou pega mais rebotes)?
# Focar nas principais qualidades de cada jogador, identificando os líderes em pontos, assistências e rebotes, o que pode ajudar a direcionar estratégias específicas (por exemplo, quem é o melhor passador para jogadas de ataque).

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'age', 'position', 'team', 'points_per_game',
#        'assists_per_game', 'rebounds_per_game'],
#       dtype='object')

# %%
player_points = df[['name', 'points_per_game']]
player_rebounds = df[['name', 'rebounds_per_game']]
player_assists = df[['name', 'assists_per_game']]

# %%
player_points
# Out:
#             name  points_per_game
# 0   LeBron James             25.7
# 1  Stephen Curry             30.4
# 2  Pascal Siakam             23.2
# 3     Chris Paul             13.0
# 4   Kyrie Irving             27.1
# 5    Rudy Gobert             15.7
# 6   Jamal Murray             20.2
# 7  Jalen Brunson             24.0

# %%
player_rebounds
# Out:
#             name  rebounds_per_game
# 0   LeBron James                8.2
# 1  Stephen Curry                5.3
# 2  Pascal Siakam                7.8
# 3     Chris Paul                4.3
# 4   Kyrie Irving                4.8
# 5    Rudy Gobert               11.6
# 6   Jamal Murray                4.0
# 7  Jalen Brunson                3.5

# %%
player_assists
# Out:
#             name  assists_per_game
# 0   LeBron James               7.4
# 1  Stephen Curry               6.2
# 2  Pascal Siakam               5.8
# 3     Chris Paul               9.2
# 4   Kyrie Irving               6.0
# 5    Rudy Gobert               1.2
# 6   Jamal Murray               6.3
# 7  Jalen Brunson               6.2

# %%
best_player_points = player_points.loc[player_points.idxmax()]

# %%
best_player_points
# Out:
#             name  points_per_game
# 1  Stephen Curry             30.4
# 1  Stephen Curry             30.4

# %%
best_player_rebounds = player_rebounds.loc[player_rebounds.idxmax()]
best_player_assists= player_assists.loc[player_assists.idxmax()]

# %%
best_player_rebounds
# Out:
#             name  rebounds_per_game
# 1  Stephen Curry                5.3
# 5    Rudy Gobert               11.6

# %%
best_player_assists
# Out:
#             name  assists_per_game
# 1  Stephen Curry               6.2
# 3     Chris Paul               9.2
